# %%
#Namen der Inseln

Inseln = [
    "Alexandra_Bank",
    "Alison_Reef",
    "Amboyna_Cay",
    "Antelope_Reef",
    "Ardasier_Reef",
    "Barque_Canada_Reef",
    "Bombay_Reef",
    "Central_Reef",
    "Collins_Reef",
    "Commodore_Reef",
    "Cornwallis_South_Reef",
    "Cuarteron_Reef",
    "Discovery_Great_Reef",
    "Drummond_Island",
    "Duncan_Islands",
    "East_Reef",
    "Erica_Reef",
    "Fiery_Cross_Reef",
    "Flat_Island",
    "Gaven_Reefs",
    "Grainger_Bank",
    "Grierson_Reef",
    "Hughes_Reef",
    "Investigator_Shoal",
    "Itu_Aba_Island",
    "Johnson_Reef",
    "Ladd_Reef",
    "Lansdowne_Reef",
    "Lincoln_Islands",
    "Loaita_Cay",
    "Loaita_Island",
    "Mariveles_Reef",
    "Middle_Island",
    "Mischief_Reef",
    "Money_Island",
    "Namyit_Island",
    "Nanshan_Island",
    "North_Island",
    "North_Reef",
    "Northeast_Cay",
    "Observation_Bank",
    "Pattle_Island",
    "Pearson_Reef",
    "Petley_Reef",
    "Prince_Consort_Bank",
    "Prince_of_Wales_Bank",
    "Quanfu_Island",
    "Rifleman_Bank",
    "Robert_Island",
    "Sand_Cay",
    "Scarborough_Shoal",
    "Second_Thomas_Shoal",
    "Sin_Cowe_Island",
    "South_Island",
    "South_Reef",
    "South_Sand",
    "Southwest_Cay",
    "Spratly_Island",
    "Subi_Reef",
    "Swallow_Reef",
    "Tennent_Reef",
    "Thitu_Island",
    "Tree_Island",
    "Triton_Island",
    "Vanguard_Bank",
    "West_Reef",
    "West_Sand",
    "West_York_Island",
    "Woody_Island",
    "Yagong_Island"
]

# %%
import os
import numpy as np
import rasterio
import pandas as pd #für .csv-Tabelle


#Funktion zur Berechnung des NDWI erstellen
def compute_ndwi(tiff_path, green_band=1, nir_band=2):
    with rasterio.open(tiff_path) as src:
        green = src.read(green_band).astype(np.float32)
        nir = src.read(nir_band).astype(np.float32)

        pixel_size = src.res[0]
        pixel_area_m2 = pixel_size ** 2

    with np.errstate(divide='ignore', invalid='ignore'):
        ndwi = (green - nir) / (green + nir)
    ndwi[np.isinf(ndwi)] = np.nan

    return ndwi, pixel_area_m2

#Funktion, um die jeweiligen vorher/nachher-TIFFs ins Script zu laden
def get_images_for_insel(insel):
    base = r"C:\Users\Windows\Desktop\Master\GIS1\TIFFs"
    s2_1 = os.path.join(base, "S2_1", f"S2_1_{insel}.tif")
    s2_2 = os.path.join(base, "S2_2", f"S2_2_{insel}.tif")

    if not os.path.exists(s2_1):
        raise FileNotFoundError(s2_1)
    if not os.path.exists(s2_2):
        raise FileNotFoundError(s2_2)

    ndwi_1, pixel_area = compute_ndwi(s2_1)
    ndwi_2, _ = compute_ndwi(s2_2)

    return ndwi_1, ndwi_2, pixel_area

# %%
results = []

#For-Schleife, die für alle Inseln anzeigt, wie viele Pixel Land waren/sind (in m²):
for insel in Inseln:
    ndwi_1, ndwi_2, pixel_area = get_images_for_insel(insel)

    land_1 = np.where(np.isnan(ndwi_1), 0, ndwi_1 <= -0.05).astype(np.uint8) #-0.05 als Schwellenwert für Land, um Wolken mit ungefähr 0 rauszufiltern
    land_2 = np.where(np.isnan(ndwi_2), 0, ndwi_2 <= -0.05).astype(np.uint8)

    land_pixels_1 = np.sum(land_1)
    land_pixels_2 = np.sum(land_2)

    land_area_1 = land_pixels_1 * pixel_area
    land_area_2 = land_pixels_2 * pixel_area

    print(f"{insel}: Landfläche vorher (S2_1) = {land_area_1:.1f} m², nachher (S2_2) = {land_area_2:.1f} m²")

    results.append({
        "insel": insel,
        "land_1": land_1,
        "land_2": land_2,
        "land_area_1_m2": land_area_1,
        "land_area_2_m2": land_area_2
    })
# Out:
# Alexandra_Bank: Landfläche vorher (S2_1) = 0.0 m², nachher (S2_2) = 23200.0 m²
# Alison_Reef: Landfläche vorher (S2_1) = 8700.0 m², nachher (S2_2) = 42200.0 m²
# Amboyna_Cay: Landfläche vorher (S2_1) = 7900.0 m², nachher (S2_2) = 22700.0 m²
# Antelope_Reef: Landfläche vorher (S2_1) = 167100.0 m², nachher (S2_2) = 35100.0 m²
# Ardasier_Reef: Landfläche vorher (S2_1) = 300.0 m², nachher (S2_2) = 5000.0 m²
# Barque_Canada_Reef: Landfläche vorher (S2_1) = 467300.0 m², nachher (S2_2) = 85900.0 m²
# Bombay_Reef: Landfläche vorher (S2_1) = 451700.0 m², nachher (S2_2) = 3200.0 m²
# Central_Reef: Landfläche vorher (S2_1) = 1406000.0 m², nachher (S2_2) = 220900.0 m²
# Collins_Reef: Landfläche vorher (S2_1) = 159700.0 m², nachher (S2_2) = 0.0 m²
# Commodore_Reef: Landfläche vorher (S2_1) = 100.0 m², nachher (S2_2) = 4700.0 m²
# Cornwallis_South_Reef: Landfläche vorher (S2_1) = 7300.0 m², nachher (S2_2) = 114300.0 m²
# Cuarteron_Reef: Landfläche vorher (S2_1) = 147600.0 m², nachher (S2_2) = 233900.0 m²
# Discovery_Great_Reef: Landfläche vorher (S2_1) = 0.0 m², nachher (S2_2) = 4100.0 m²
# Drummond_Island: Landfläche vorher (S2_1) = 374500.0 m², nachher (S2_2) = 215400.0 m²
# Duncan_Islands: Landfläche vorher (S2_1) = 657900.0 m², nachher (S2_2) = 696400.0 m²
# East_Reef: Landfläche vorher (S2_1) = 0.0 m², nachher (S2_2) = 29300.0 m²
# Erica_Reef: Landfläche vorher (S2_1) = 16500.0 m², nachher (S2_2) = 10500.0 m²
# Fiery_Cross_Reef: Landfläche vorher (S2_1) = 9100.0 m², nachher (S2_2) = 2742000.0 m²
# Flat_Island: Landfläche vorher (S2_1) = 298900.0 m², nachher (S2_2) = 9600.0 m²
# Gaven_Reefs: Landfläche vorher (S2_1) = 114800.0 m², nachher (S2_2) = 125600.0 m²
# Grainger_Bank: Landfläche vorher (S2_1) = 24700.0 m², nachher (S2_2) = 17100.0 m²
# Grierson_Reef: Landfläche vorher (S2_1) = 28000.0 m², nachher (S2_2) = 103300.0 m²
# Hughes_Reef: Landfläche vorher (S2_1) = 62400.0 m², nachher (S2_2) = 77700.0 m²
# Investigator_Shoal: Landfläche vorher (S2_1) = 3502300.0 m², nachher (S2_2) = 21000.0 m²
# Itu_Aba_Island: Landfläche vorher (S2_1) = 475700.0 m², nachher (S2_2) = 453000.0 m²
# Johnson_Reef: Landfläche vorher (S2_1) = 1501600.0 m², nachher (S2_2) = 105300.0 m²
# Ladd_Reef: Landfläche vorher (S2_1) = 0.0 m², nachher (S2_2) = 517200.0 m²
# Lansdowne_Reef: Landfläche vorher (S2_1) = 58000.0 m², nachher (S2_2) = 36500.0 m²
# Lincoln_Islands: Landfläche vorher (S2_1) = 1561600.0 m², nachher (S2_2) = 1837100.0 m²
# Loaita_Cay: Landfläche vorher (S2_1) = 19700.0 m², nachher (S2_2) = 8200.0 m²
# Loaita_Island: Landfläche vorher (S2_1) = 81000.0 m², nachher (S2_2) = 70800.0 m²
# Mariveles_Reef: Landfläche vorher (S2_1) = 506000.0 m², nachher (S2_2) = 13600.0 m²
# Middle_Island: Landfläche vorher (S2_1) = 132100.0 m², nachher (S2_2) = 129000.0 m²
# Mischief_Reef: Landfläche vorher (S2_1) = 3948800.0 m², nachher (S2_2) = 5922900.0 m²
# Money_Island: Landfläche vorher (S2_1) = 697800.0 m², nachher (S2_2) = 410400.0 m²
# Namyit_Island: Landfläche vorher (S2_1) = 124900.0 m², nachher (S2_2) = 672800.0 m²
# Nanshan_Island: Landfläche vorher (S2_1) = 185700.0 m², nachher (S2_2) = 71600.0 m²
# North_Island: Landfläche vorher (S2_1) = 13700.0 m², nachher (S2_2) = 458100.0 m²
# North_Reef: Landfläche vorher (S2_1) = 361900.0 m², nachher (S2_2) = 900.0 m²
# Northeast_Cay: Landfläche vorher (S2_1) = 91700.0 m², nachher (S2_2) = 152200.0 m²
# Observation_Bank: Landfläche vorher (S2_1) = 108200.0 m², nachher (S2_2) = 17200.0 m²
# Pattle_Island: Landfläche vorher (S2_1) = 208800.0 m², nachher (S2_2) = 317100.0 m²
# Pearson_Reef: Landfläche vorher (S2_1) = 1732400.0 m², nachher (S2_2) = 632300.0 m²
# Petley_Reef: Landfläche vorher (S2_1) = 4300.0 m², nachher (S2_2) = 88300.0 m²
# Prince_Consort_Bank: Landfläche vorher (S2_1) = 84200.0 m², nachher (S2_2) = 57600.0 m²
# Prince_of_Wales_Bank: Landfläche vorher (S2_1) = 0.0 m², nachher (S2_2) = 10900.0 m²
# Quanfu_Island: Landfläche vorher (S2_1) = 78700.0 m², nachher (S2_2) = 29000.0 m²
# Rifleman_Bank: Landfläche vorher (S2_1) = 125500.0 m², nachher (S2_2) = 4000.0 m²
# Robert_Island: Landfläche vorher (S2_1) = 309800.0 m², nachher (S2_2) = 330000.0 m²
# Sand_Cay: Landfläche vorher (S2_1) = 62100.0 m², nachher (S2_2) = 359400.0 m²
# Scarborough_Shoal: Landfläche vorher (S2_1) = 704500.0 m², nachher (S2_2) = 352700.0 m²
# Second_Thomas_Shoal: Landfläche vorher (S2_1) = 78700.0 m², nachher (S2_2) = 579900.0 m²
# Sin_Cowe_Island: Landfläche vorher (S2_1) = 135000.0 m², nachher (S2_2) = 132500.0 m²
# South_Island: Landfläche vorher (S2_1) = 112800.0 m², nachher (S2_2) = 122700.0 m²
# South_Reef: Landfläche vorher (S2_1) = 132100.0 m², nachher (S2_2) = 490600.0 m²
# South_Sand: Landfläche vorher (S2_1) = 50300.0 m², nachher (S2_2) = 60100.0 m²
# Southwest_Cay: Landfläche vorher (S2_1) = 200700.0 m², nachher (S2_2) = 188100.0 m²
# Spratly_Island: Landfläche vorher (S2_1) = 0.0 m², nachher (S2_2) = 394300.0 m²
# Subi_Reef: Landfläche vorher (S2_1) = 34100.0 m², nachher (S2_2) = 293600.0 m²
# Swallow_Reef: Landfläche vorher (S2_1) = 323300.0 m², nachher (S2_2) = 3400.0 m²
# Tennent_Reef: Landfläche vorher (S2_1) = 2481700.0 m², nachher (S2_2) = 631600.0 m²
# Thitu_Island: Landfläche vorher (S2_1) = 374800.0 m², nachher (S2_2) = 372000.0 m²
# Tree_Island: Landfläche vorher (S2_1) = 332700.0 m², nachher (S2_2) = 290800.0 m²
# Triton_Island: Landfläche vorher (S2_1) = 0.0 m², nachher (S2_2) = 1089100.0 m²
# Vanguard_Bank: Landfläche vorher (S2_1) = 0.0 m², nachher (S2_2) = 16900.0 m²
# West_Reef: Landfläche vorher (S2_1) = 400.0 m², nachher (S2_2) = 129800.0 m²
# West_Sand: Landfläche vorher (S2_1) = 396000.0 m², nachher (S2_2) = 237600.0 m²
# West_York_Island: Landfläche vorher (S2_1) = 191100.0 m², nachher (S2_2) = 192100.0 m²
# Woody_Island: Landfläche vorher (S2_1) = 2646900.0 m², nachher (S2_2) = 3241900.0 m²
# Yagong_Island: Landfläche vorher (S2_1) = 15000.0 m², nachher (S2_2) = 8800.0 m²

# %%
#For-Schleife, die final ausrechnet wie viele m² dazugewonnen wurden:
for island_result in results:
    insel = island_result["insel"]
    area_1 = island_result["land_area_1_m2"]
    area_2 = island_result["land_area_2_m2"]

    diff = area_2 - area_1
    
    if diff > 0:
        status = "Landgewinn"
    elif diff < 0:
        status = "Verlust (Wolken?)"
    else:
        status = "unverändert"

    print(
        f"{insel}: {status} "
        f"({diff:+.0f} m²)" #.0 = keine Nachkommastellen
    )
# Out:
# Alexandra_Bank: Landgewinn (+23200 m²)
# Alison_Reef: Landgewinn (+33500 m²)
# Amboyna_Cay: Landgewinn (+14800 m²)
# Antelope_Reef: Verlust (Wolken?) (-132000 m²)
# Ardasier_Reef: Landgewinn (+4700 m²)
# Barque_Canada_Reef: Verlust (Wolken?) (-381400 m²)
# Bombay_Reef: Verlust (Wolken?) (-448500 m²)
# Central_Reef: Verlust (Wolken?) (-1185100 m²)
# Collins_Reef: Verlust (Wolken?) (-159700 m²)
# Commodore_Reef: Landgewinn (+4600 m²)
# Cornwallis_South_Reef: Landgewinn (+107000 m²)
# Cuarteron_Reef: Landgewinn (+86300 m²)
# Discovery_Great_Reef: Landgewinn (+4100 m²)
# Drummond_Island: Verlust (Wolken?) (-159100 m²)
# Duncan_Islands: Landgewinn (+38500 m²)
# East_Reef: Landgewinn (+29300 m²)
# Erica_Reef: Verlust (Wolken?) (-6000 m²)
# Fiery_Cross_Reef: Landgewinn (+2732900 m²)
# Flat_Island: Verlust (Wolken?) (-289300 m²)
# Gaven_Reefs: Landgewinn (+10800 m²)
# Grainger_Bank: Verlust (Wolken?) (-7600 m²)
# Grierson_Reef: Landgewinn (+75300 m²)
# Hughes_Reef: Landgewinn (+15300 m²)
# Investigator_Shoal: Verlust (Wolken?) (-3481300 m²)
# Itu_Aba_Island: Verlust (Wolken?) (-22700 m²)
# Johnson_Reef: Verlust (Wolken?) (-1396300 m²)
# Ladd_Reef: Landgewinn (+517200 m²)
# Lansdowne_Reef: Verlust (Wolken?) (-21500 m²)
# Lincoln_Islands: Landgewinn (+275500 m²)
# Loaita_Cay: Verlust (Wolken?) (-11500 m²)
# Loaita_Island: Verlust (Wolken?) (-10200 m²)
# Mariveles_Reef: Verlust (Wolken?) (-492400 m²)
# Middle_Island: Verlust (Wolken?) (-3100 m²)
# Mischief_Reef: Landgewinn (+1974100 m²)
# Money_Island: Verlust (Wolken?) (-287400 m²)
# Namyit_Island: Landgewinn (+547900 m²)
# Nanshan_Island: Verlust (Wolken?) (-114100 m²)
# North_Island: Landgewinn (+444400 m²)
# North_Reef: Verlust (Wolken?) (-361000 m²)
# Northeast_Cay: Landgewinn (+60500 m²)
# Observation_Bank: Verlust (Wolken?) (-91000 m²)
# Pattle_Island: Landgewinn (+108300 m²)
# Pearson_Reef: Verlust (Wolken?) (-1100100 m²)
# Petley_Reef: Landgewinn (+84000 m²)
# Prince_Consort_Bank: Verlust (Wolken?) (-26600 m²)
# Prince_of_Wales_Bank: Landgewinn (+10900 m²)
# Quanfu_Island: Verlust (Wolken?) (-49700 m²)
# Rifleman_Bank: Verlust (Wolken?) (-121500 m²)
# Robert_Island: Landgewinn (+20200 m²)
# Sand_Cay: Landgewinn (+297300 m²)
# Scarborough_Shoal: Verlust (Wolken?) (-351800 m²)
# Second_Thomas_Shoal: Landgewinn (+501200 m²)
# Sin_Cowe_Island: Verlust (Wolken?) (-2500 m²)
# South_Island: Landgewinn (+9900 m²)
# South_Reef: Landgewinn (+358500 m²)
# South_Sand: Landgewinn (+9800 m²)
# Southwest_Cay: Verlust (Wolken?) (-12600 m²)
# Spratly_Island: Landgewinn (+394300 m²)
# Subi_Reef: Landgewinn (+259500 m²)
# Swallow_Reef: Verlust (Wolken?) (-319900 m²)
# Tennent_Reef: Verlust (Wolken?) (-1850100 m²)
# Thitu_Island: Verlust (Wolken?) (-2800 m²)
# Tree_Island: Verlust (Wolken?) (-41900 m²)
# Triton_Island: Landgewinn (+1089100 m²)
# Vanguard_Bank: Landgewinn (+16900 m²)
# West_Reef: Landgewinn (+129400 m²)
# West_Sand: Verlust (Wolken?) (-158400 m²)
# West_York_Island: Landgewinn (+1000 m²)
# Woody_Island: Landgewinn (+595000 m²)
# Yagong_Island: Verlust (Wolken?) (-6200 m²)

# %%
#.csv-Tabelle mit Ergebnissen erstellen lassen

rows = []

for result in results:
    land_2018 = result["land_area_1_m2"]
    land_2025 = result["land_area_2_m2"]
    diff = land_2025 - land_2018

    rows.append({
        "Name": result["insel"],
        "Landfläche 2018 [m²]": land_2018,
        "Landfläche 2025 [m²]": land_2025,
        "Differenz der Landflächen [m²]": diff
    })

df = pd.DataFrame(rows)

csv_path = r"C:\Users\Windows\Desktop\Master\GIS1/Landgewinn_Daten.csv"
df.to_csv(csv_path, index=False, encoding="utf-8-sig") #utf-8-sig kümmert sich um Sonderzeichen wie ä und ²

print(f"Tabelle gespeichert unter: {csv_path}")
# Out:
# Tabelle gespeichert unter: C:\Users\Windows\Desktop\Master\GIS1/Landgewinn_Daten.csv
